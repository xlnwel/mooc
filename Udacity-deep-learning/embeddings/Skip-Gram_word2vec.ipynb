# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](https://github.com/xlnwel/deep-learning/blob/master/embeddings/assets/one_hot_encoding.png?raw=1)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](https://github.com/xlnwel/deep-learning/blob/master/embeddings/assets/lookup_matrix.png?raw=1)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='https://github.com/xlnwel/deep-learning/blob/master/embeddings/assets/tokenize_lookup.png?raw=1' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="https://github.com/xlnwel/deep-learning/blob/master/embeddings/assets/word2vec_architectures.png?raw=1" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# !git clone https://github.com/xlnwel/deep-learning.git
# %cd deep-learning/embeddings
# Out:
# Cloning into 'deep-learning'...
# remote: Counting objects: 1463, done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 1463 (delta 0), reused 0 (delta 0), pack-reused 1458
# Receiving objects: 100% (1463/1463), 78.78 MiB | 37.33 MiB/s, done.
# Resolving deltas: 100% (616/616), done.
# /content/deep-learning/embeddings/deep-learning/embeddings

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
# !pip install tqdm
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.24.0)
# Text8 Dataset: 31.4MB [00:14, 2.10MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
from math import sqrt

t = 1e-3
print(len(int_words))
word_frequencies = Counter(int_words)
total = len(int_words)
drop_rate = {word: 1 - sqrt(t/count*total) for word, count in word_frequencies.items()}
train_words = [word for word in int_words if random.random() > drop_rate[word]]
print(len(train_words))
# Out:
# 16680599
# 11660925

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, window_size)

    targets = set(words[idx-R if idx-R > 0 else 0: idx] + words[idx: idx+R])
    return list(targets)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](https://github.com/xlnwel/deep-learning/blob/master/embeddings/assets/skip_gram_net_arch.png?raw=1)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, None)

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding)))
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)))
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, 
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-43-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.5885 0.0373 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 15.3804 0.0295 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 13.8324 0.0301 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 13.2299 0.0290 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 11.9772 0.0292 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 11.5877 0.0297 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 11.3417 0.0303 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 10.8513 0.0295 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 10.8905 0.0300 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 10.3791 0.0301 sec/batch
# Nearest to will: positronic, pp, saxon, be, galilee, hironaka, much, loathing,
# Nearest to s: did, eradicated, archipelagoes, quiet, lsp, urogenital, hated, positions,
# Nearest to seven: created, westcott, iconography, finely, has, stratton, except, king,
# Nearest to world: ourense, foundries, auvergne, intermedia, hesitant, prepositioning, part, concr,
# Nearest to history: mangeshkar, incapacity, was, concerned, aside, arbitral, corporatist, backdrop,
# Nearest to as: recorded, monarchs, no, pflp, created, tears, although, gives,
# Nearest to often: wolcott, family, probably, anna, hoofed, professors, offshoot, but,
# Nearest to his: smuggled, created, waste, george, most, visitor, see, forgery,
# Nearest to san: created, operate, mrl, klondike, cris, posed, feather, rodrigo,
# Nearest to nobel: plus, generate, derivatives, family, nola, marshalling, cyrene, look,
# Nearest to heavy: electrodynamics, robert, video, josiah, divert, text, architectures, plasmodium,
# Nearest to grand: irwin, although, created, abracadabra, othniel, quotas, showmanship, packets,
# Nearest to police: whitewater, harlem, budding, onward, minbari, advantage, lsd, investigating,
# Nearest to derived: supergroup, farc, town, five, kingdom, minute, sn, combatants,
# Nearest to resources: achievements, active, dundas, efforts, did, ravaged, bunny, polydor,
# Nearest to prince: visitor, christendom, insert, submitted, daubert, mandrakelinux, hutchins, hesitant,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 10.3341 0.0311 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 10.1480 0.0301 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 10.0577 0.0302 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 9.7351 0.0304 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 9.6812 0.0305 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 9.5697 0.0303 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 9.1915 0.0301 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 9.3464 0.0300 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 9.1628 0.0299 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 9.1065 0.0304 sec/batch
# Nearest to will: be, have, of, through, over, who, a, new,
# Nearest to s: time, in, this, to, did, of, and, during,
# Nearest to seven: has, of, over, five, as, is, up, in,
# Nearest to world: in, a, of, part, to, into, more, are,
# Nearest to history: was, see, a, in, about, by, an, over,
# Nearest to as: on, no, for, most, recorded, it, although, is,
# Nearest to often: but, called, a, is, much, of, from, that,
# Nearest to his: most, see, part, in, on, only, seven, a,
# Nearest to san: created, much, a, operate, six, west, has, with,
# Nearest to nobel: many, plus, as, for, look, to, most, also,
# Nearest to heavy: three, time, as, no, robert, zero, video, who,
# Nearest to grand: countries, although, or, they, in, more, for, including,
# Nearest to police: from, or, they, about, are, because, a, all,
# Nearest to derived: five, it, up, kingdom, supergroup, town, three, after,
# Nearest to resources: the, by, did, an, but, it, at, efforts,
# Nearest to prince: see, a, of, being, much, in, over, more,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 8.8962 0.0311 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 8.7884 0.0301 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 8.7597 0.0299 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 8.9185 0.0301 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 8.6679 0.0301 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 8.4595 0.0301 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 8.5195 0.0305 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 8.2810 0.0304 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 7.9839 0.0302 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 8.3734 0.0305 sec/batch
# Nearest to will: be, to, a, have, of, through, in, who,
# Nearest to s: in, to, of, and, the, this, for, time,
# Nearest to seven: zero, has, of, to, on, five, in, two,
# Nearest to world: in, a, of, the, to, on, from, are,
# Nearest to history: in, a, was, to, the, by, of, see,
# Nearest to as: on, for, which, a, in, it, no, is,
# Nearest to often: but, a, is, of, in, called, the, that,
# Nearest to his: most, in, and, the, a, see, on, to,
# Nearest to san: a, much, with, the, created, has, in, six,
# Nearest to nobel: many, for, to, also, as, on, was, most,
# Nearest to heavy: as, other, time, no, this, that, in, is,
# Nearest to grand: to, a, more, for, in, or, from, the,
# Nearest to police: from, a, or, are, they, to, all, then,
# Nearest to derived: it, of, in, five, other, up, to, with,
# Nearest to resources: the, by, it, but, in, an, to, at,
# Nearest to prince: a, see, of, the, which, being, in, much,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 8.0598 0.0313 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 8.1201 0.0300 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 8.0507 0.0300 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 8.1160 0.0300 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 8.4205 0.0297 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 8.1570 0.0310 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 8.1061 0.0311 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 8.0109 0.0299 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 8.0663 0.0304 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 7.5838 0.0305 sec/batch
# Nearest to will: be, that, to, on, of, a, only, have,
# Nearest to s: this, in, the, of, and, to, for, a,
# Nearest to seven: zero, two, five, on, four, three, eight, in,
# Nearest to world: in, a, of, the, when, to, on, from,
# Nearest to history: in, to, the, a, was, of, by, but,
# Nearest to as: a, in, the, for, which, of, to, on,
# Nearest to often: most, that, is, but, as, to, the, a,
# Nearest to his: most, the, and, also, of, on, in, to,
# Nearest to san: much, with, the, to, they, created, including, six,
# Nearest to nobel: many, century, these, because, also, most, was, their,
# Nearest to heavy: that, other, this, these, most, is, during, time,
# Nearest to grand: or, more, some, be, including, to, from, their,
# Nearest to police: from, or, a, they, would, then, are, because,
# Nearest to derived: it, most, other, of, in, from, is, this,
# Nearest to resources: the, it, by, in, to, an, only, but,
# Nearest to prince: see, part, that, of, much, being, more, after,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 7.4698 0.0314 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 7.7541 0.0304 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 7.5989 0.0305 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 7.6789 0.0298 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 7.5121 0.0297 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 7.5488 0.0302 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 7.7751 0.0301 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 7.5033 0.0306 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 7.6079 0.0301 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 7.1009 0.0304 sec/batch
# Nearest to will: be, that, only, an, this, is, it, about,
# Nearest to s: this, the, of, from, in, first, on, and,
# Nearest to seven: zero, two, five, eight, one, four, three, six,
# Nearest to world: when, after, this, from, into, most, during, on,
# Nearest to history: first, this, was, see, while, but, over, so,
# Nearest to as: well, the, a, such, to, of, this, that,
# Nearest to often: most, is, that, such, are, these, called, but,
# Nearest to his: most, was, this, on, after, while, only, from,
# Nearest to san: much, around, created, was, they, six, first, including,
# Nearest to nobel: these, many, century, make, four, because, were, one,
# Nearest to heavy: these, that, during, time, this, most, but, who,
# Nearest to grand: or, them, some, but, from, may, including, his,
# Nearest to police: or, from, any, usually, then, would, about, around,
# Nearest to derived: most, is, or, other, those, this, it, can,
# Nearest to resources: only, all, this, its, it, their, but, is,
# Nearest to prince: see, after, part, that, being, over, much, above,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 7.0501 0.0313 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 7.2449 0.0300 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 7.1334 0.0298 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 7.2108 0.0305 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 7.2318 0.0303 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 7.3019 0.0309 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 7.1303 0.0308 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 7.2054 0.0311 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 7.1297 0.0314 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 7.0369 0.0309 sec/batch
# Nearest to will: only, be, that, so, all, it, this, or,
# Nearest to s: the, first, in, from, was, of, this, one,
# Nearest to seven: eight, five, one, zero, four, six, three, two,
# Nearest to world: after, during, first, being, up, all, through, where,
# Nearest to history: over, first, see, much, his, while, would, so,
# Nearest to as: such, well, a, that, this, some, known, the,
# Nearest to often: most, is, that, used, such, this, or, all,
# Nearest to his: he, after, part, but, first, own, was, being,
# Nearest to san: much, around, six, eight, created, united, world, his,
# Nearest to nobel: make, century, since, end, work, many, following, were,
# Nearest to heavy: smaller, much, around, works, provide, would, so, free,
# Nearest to grand: his, them, countries, like, king, home, under, much,
# Nearest to police: any, around, then, about, having, usually, or, out,
# Nearest to derived: those, most, or, can, people, use, even, any,
# Nearest to resources: all, did, according, although, along, now, end, than,
# Nearest to prince: much, after, part, become, being, later, see, around,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 6.9917 0.0318 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 7.6401 0.0302 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 7.1753 0.0311 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 6.9758 0.0309 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 6.6985 0.0313 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 6.8450 0.0312 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 6.7415 0.0302 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 6.9237 0.0305 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 6.8886 0.0301 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 7.0503 0.0305 sec/batch
# Nearest to will: so, all, be, them, would, same, they, thus,
# Nearest to s: the, was, on, after, in, of, from, when,
# Nearest to seven: five, eight, six, one, four, nine, zero, three,
# Nearest to world: around, after, since, he, until, war, during, long,
# Nearest to history: early, work, much, life, long, until, over, important,
# Nearest to as: such, well, known, a, that, this, is, the,
# Nearest to often: used, most, but, called, or, these, however, is,
# Nearest to his: he, after, work, own, later, early, him, while,
# Nearest to san: man, around, much, just, created, under, united, life,
# Nearest to nobel: century, us, late, half, end, factors, work, make,
# Nearest to heavy: around, smaller, provide, much, works, earlier, free, either,
# Nearest to grand: countries, i, related, king, home, though, against, said,
# Nearest to police: study, around, having, out, usually, further, non, changes,
# Nearest to derived: any, those, use, similar, people, various, generally, these,
# Nearest to resources: did, according, along, now, people, states, different, those,
# Nearest to prince: become, much, after, part, he, later, his, under,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 6.9293 0.0319 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 6.8741 0.0307 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 6.5580 0.0306 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 6.7229 0.0310 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 6.7182 0.0303 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 6.7481 0.0305 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 6.8069 0.0301 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 6.7680 0.0300 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 6.6951 0.0302 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 6.8107 0.0298 sec/batch
# Nearest to will: them, if, may, would, they, within, use, make,
# Nearest to s: the, in, of, from, to, on, was, an,
# Nearest to seven: six, eight, five, nine, four, one, three, zero,
# Nearest to world: war, since, ii, being, he, around, following, all,
# Nearest to history: main, article, important, much, life, became, early, according,
# Nearest to as: such, well, known, the, a, some, this, that,
# Nearest to often: used, sometimes, most, or, even, common, since, is,
# Nearest to his: he, him, own, after, became, life, later, work,
# Nearest to san: man, established, created, government, according, future, day, king,
# Nearest to nobel: century, factors, th, late, half, parts, times, country,
# Nearest to heavy: smaller, despite, free, either, earlier, countries, similar, parts,
# Nearest to grand: king, using, frequently, countries, itself, said, written, i,
# Nearest to police: study, once, further, former, government, having, military, started,
# Nearest to derived: people, any, similar, those, modern, various, important, name,
# Nearest to resources: according, states, along, did, common, now, areas, groups,
# Nearest to prince: book, become, complete, good, life, war, country, despite,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 6.6077 0.0311 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 6.4717 0.0300 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 6.4883 0.0299 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 6.4448 0.0299 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 6.5070 0.0297 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 6.2600 0.0304 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 6.5210 0.0299 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 6.3996 0.0297 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 6.7684 0.0299 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 6.3942 0.0301 sec/batch
# Nearest to will: if, make, use, thus, each, them, would, those,
# Nearest to s: the, in, of, and, from, for, on, a,
# Nearest to seven: eight, one, five, nine, six, four, three, zero,
# Nearest to world: ii, war, end, states, people, according, around, he,
# Nearest to history: important, life, article, main, third, early, great, according,
# Nearest to as: such, well, known, the, a, that, of, is,
# Nearest to often: used, is, example, most, since, considered, sometimes, still,
# Nearest to his: he, after, was, him, later, during, own, time,
# Nearest to san: king, created, came, established, british, government, sent, study,
# Nearest to nobel: prize, german, throughout, style, us, british, th, factors,
# Nearest to heavy: despite, smaller, free, itself, provide, systems, human, earlier,
# Nearest to grand: king, countries, makes, frequently, itself, written, title, said,
# Nearest to police: study, himself, entire, started, government, military, having, created,
# Nearest to derived: name, people, word, those, language, origin, human, land,
# Nearest to resources: natural, parts, groups, available, areas, particularly, countries, human,
# Nearest to prince: king, french, british, created, country, book, city, become,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 6.4481 0.0314 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 6.4238 0.0302 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 6.3314 0.0303 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 6.4414 0.0302 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 6.8517 0.0305 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 6.8302 0.0307 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 6.7156 0.0303 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 6.2433 0.0310 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 6.1657 0.0293 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 6.5061 0.0295 sec/batch
# Nearest to will: make, if, each, does, must, thus, always, because,
# Nearest to s: the, in, of, and, from, a, to, was,
# Nearest to seven: eight, one, six, nine, five, four, three, zero,
# Nearest to world: ii, war, end, during, around, until, according, third,
# Nearest to history: official, article, century, important, life, today, study, sources,
# Nearest to as: well, such, known, a, the, of, but, and,
# Nearest to often: is, used, most, the, since, it, usually, sometimes,
# Nearest to his: he, him, work, was, made, later, time, after,
# Nearest to san: study, sent, future, established, itself, expanded, public, includes,
# Nearest to nobel: prize, german, subsequent, british, written, french, opened, series,
# Nearest to heavy: free, human, therefore, systems, smaller, set, countries, always,
# Nearest to grand: countries, makes, king, central, largely, here, title, largest,
# Nearest to police: study, military, central, moved, put, whose, family, run,
# Nearest to derived: word, language, name, origin, sources, political, countries, frequently,
# Nearest to resources: natural, countries, parts, available, land, series, particularly, list,
# Nearest to prince: french, king, good, william, charles, book, city, son,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 6.5542 0.0306 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 6.5655 0.0295 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 6.4767 0.0297 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 6.4177 0.0302 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 6.4399 0.0302 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 6.0651 0.0301 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 6.0862 0.0302 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 6.3559 0.0295 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 6.3104 0.0297 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 6.1854 0.0299 sec/batch
# Nearest to will: make, if, this, use, number, is, instead, it,
# Nearest to s: the, of, in, and, a, from, first, on,
# Nearest to seven: one, eight, six, nine, five, four, three, two,
# Nearest to world: ii, war, during, end, until, since, the, states,
# Nearest to history: article, early, century, life, throughout, important, today, produced,
# Nearest to as: such, well, known, is, the, a, this, of,
# Nearest to often: is, used, most, are, the, a, it, in,
# Nearest to his: he, him, own, was, during, to, the, after,
# Nearest to san: prior, expanded, record, city, future, established, includes, sent,
# Nearest to nobel: prize, german, french, british, writer, subsequent, us, director,
# Nearest to heavy: actual, constructed, free, need, practice, money, throughout, systems,
# Nearest to grand: countries, cultural, nation, makes, response, positions, largest, king,
# Nearest to police: put, run, heavily, forces, military, created, responsible, opposed,
# Nearest to derived: word, sources, nature, language, origin, human, frequently, probably,
# Nearest to resources: natural, sources, cultural, countries, parts, series, land, idea,
# Nearest to prince: charles, french, king, country, british, book, good, city,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 6.2294 0.0312 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 6.3102 0.0301 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 6.1812 0.0303 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 6.1845 0.0301 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 6.2358 0.0303 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 6.1824 0.0302 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 6.2019 0.0133 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 6.3045 0.0299 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 6.0533 0.0299 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 6.1298 0.0299 sec/batch
# Nearest to will: if, seen, down, use, never, is, because, make,
# Nearest to s: the, in, of, and, a, on, by, was,
# Nearest to seven: nine, eight, one, six, five, four, three, zero,
# Nearest to world: the, of, in, ii, around, war, until, during,
# Nearest to history: article, of, early, life, established, today, throughout, written,
# Nearest to as: such, well, known, is, a, the, and, that,
# Nearest to often: is, used, the, most, are, this, use, it,
# Nearest to his: he, him, was, after, to, the, of, and,
# Nearest to san: future, expanded, france, running, prior, city, events, achieved,
# Nearest to nobel: prize, british, german, physicist, writer, chemist, french, b,
# Nearest to heavy: constructed, difficult, lack, actual, purposes, money, space, places,
# Nearest to grand: focus, nation, success, makes, added, british, force, federal,
# Nearest to police: heavily, serve, responsible, military, run, forces, opposed, army,
# Nearest to derived: word, nature, language, origin, frequently, human, sources, involved,
# Nearest to resources: natural, parts, issues, land, community, sources, continues, future,
# Nearest to prince: king, british, charles, france, visited, french, city, good,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 6.0965 0.0308 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 6.1067 0.0302 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 6.1134 0.0299 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 6.0636 0.0298 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 6.1025 0.0306 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 5.9423 0.0292 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 5.9899 0.0293 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 6.0989 0.0296 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 6.1547 0.0302 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 6.1782 0.0302 sec/batch
# Nearest to will: that, all, make, to, it, they, this, be,
# Nearest to s: the, in, of, on, was, and, a, to,
# Nearest to seven: one, nine, eight, six, five, three, four, two,
# Nearest to world: war, during, ii, the, in, around, to, of,
# Nearest to history: early, style, today, ancient, record, important, of, culture,
# Nearest to as: such, well, is, known, the, a, of, that,
# Nearest to often: most, is, used, are, the, with, even, to,
# Nearest to his: he, was, him, the, of, in, after, died,
# Nearest to san: francisco, prior, running, future, city, currently, women, record,
# Nearest to nobel: prize, chemist, laureate, physicist, recipient, peace, german, british,
# Nearest to heavy: purposes, invasion, perceived, constructed, controversial, lack, represent, agreement,
# Nearest to grand: nation, declared, team, powers, british, event, added, battle,
# Nearest to police: military, secret, heavily, field, moving, security, indeed, tried,
# Nearest to derived: word, origin, meaning, language, frequently, names, latin, probably,
# Nearest to resources: natural, continues, issues, section, industry, land, freedom, provides,
# Nearest to prince: british, joseph, military, iii, king, entitled, treaty, charles,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 6.0386 0.0310 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 6.0599 0.0303 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 6.0252 0.0300 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 5.7771 0.0300 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 5.9202 0.0302 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 5.9237 0.0302 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 5.8143 0.0303 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 5.8521 0.0301 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 5.9096 0.0299 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 6.0168 0.0304 sec/batch
# Nearest to will: it, they, to, that, not, be, make, them,
# Nearest to s: the, in, of, was, and, by, to, a,
# Nearest to seven: eight, nine, one, six, three, five, four, zero,
# Nearest to world: war, in, the, ii, during, around, from, and,
# Nearest to history: of, the, in, early, throughout, s, and, great,
# Nearest to as: such, well, known, the, a, is, in, that,
# Nearest to often: used, is, most, are, in, to, the, such,
# Nearest to his: he, him, was, the, after, own, to, and,
# Nearest to san: francisco, replace, magazine, prior, expanded, women, value, running,
# Nearest to nobel: prize, chemist, laureate, physicist, recipient, winners, writer, application,
# Nearest to heavy: purposes, light, represent, fixed, space, invasion, controversial, purpose,
# Nearest to grand: nation, positions, team, extended, execution, mass, organized, moving,
# Nearest to police: security, secret, moving, positions, kept, military, value, field,
# Nearest to derived: word, meaning, origin, language, sources, latin, names, likely,
# Nearest to resources: natural, issues, continues, section, provides, freedom, marked, online,
# Nearest to prince: love, visited, administration, she, tried, london, daughter, edward,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 5.8375 0.0317 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 5.7812 0.0308 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 5.7504 0.0307 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 5.6509 0.0306 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 5.6230 0.0301 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 5.7836 0.0305 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 5.8078 0.0299 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 5.7198 0.0300 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 5.9398 0.0303 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 5.8629 0.0300 sec/batch
# Nearest to will: that, to, it, be, is, this, a, all,
# Nearest to s: the, of, by, was, in, and, a, to,
# Nearest to seven: eight, six, one, nine, five, four, three, zero,
# Nearest to world: war, ii, the, of, in, third, to, around,
# Nearest to history: under, of, early, the, english, ancient, books, important,
# Nearest to as: such, well, is, of, known, to, the, that,
# Nearest to often: is, used, are, this, that, with, most, for,
# Nearest to his: he, him, was, after, to, the, life, first,
# Nearest to san: francisco, replace, diego, expanded, italy, california, offices, founding,
# Nearest to nobel: prize, chemist, laureate, physicist, recipient, winners, swiss, peace,
# Nearest to heavy: money, perceived, section, represent, purposes, purpose, round, space,
# Nearest to grand: team, teaching, execution, centre, campaign, event, title, money,
# Nearest to police: security, defense, controlled, recognition, foreign, powers, achieve, myth,
# Nearest to derived: word, meaning, names, latin, separate, origin, entirely, refers,
# Nearest to resources: issues, provides, freedom, environment, ideas, food, section, services,
# Nearest to prince: visited, treaty, grand, selected, tried, proper, love, foreign,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 5.9438 0.0310 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 6.0512 0.0300 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 5.8779 0.0299 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 5.8109 0.0302 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 5.7476 0.0302 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 5.6804 0.0307 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 5.6804 0.0300 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 5.9094 0.0305 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 5.8801 0.0305 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 5.7415 0.0305 sec/batch
# Nearest to will: that, it, be, they, to, is, this, but,
# Nearest to s: zero, one, the, two, nine, seven, in, four,
# Nearest to seven: one, eight, nine, five, six, zero, four, two,
# Nearest to world: war, the, ii, during, around, of, in, and,
# Nearest to history: early, of, the, about, century, article, ancient, important,
# Nearest to as: such, well, a, the, is, known, to, but,
# Nearest to often: used, is, most, are, or, usually, as, that,
# Nearest to his: he, was, him, the, to, with, on, life,
# Nearest to san: francisco, replace, diego, street, bay, california, running, places,
# Nearest to nobel: prize, laureate, chemist, recipient, physicist, winners, swiss, eric,
# Nearest to heavy: money, round, represent, perceived, bodies, practical, invasion, producing,
# Nearest to grand: emerged, nation, execution, team, dutch, centre, positions, mean,
# Nearest to police: positions, australian, base, defense, achieve, retired, headquarters, training,
# Nearest to derived: word, meaning, names, origin, terms, elements, likely, whole,
# Nearest to resources: provides, expected, extensive, environment, cities, organization, formation, issues,
# Nearest to prince: edward, visited, treaty, love, administration, henry, subsequently, russia,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 5.7574 0.0314 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 5.8758 0.0299 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 5.8062 0.0301 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 5.9631 0.0300 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 5.7734 0.0300 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 5.7251 0.0301 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 5.5083 0.0297 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 5.5722 0.0310 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 5.5818 0.0307 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 5.5746 0.0313 sec/batch
# Nearest to will: be, that, they, make, not, it, to, those,
# Nearest to s: the, in, of, on, by, a, zero, from,
# Nearest to seven: nine, one, six, eight, four, five, three, two,
# Nearest to world: the, war, in, of, and, to, during, many,
# Nearest to history: of, the, in, early, on, and, first, world,
# Nearest to as: such, well, the, that, is, of, a, known,
# Nearest to often: used, is, are, that, for, or, the, it,
# Nearest to his: he, was, him, the, father, work, after, first,
# Nearest to san: francisco, california, replace, diego, street, bay, running, office,
# Nearest to nobel: prize, laureate, chemist, physicist, recipient, swiss, winners, medicine,
# Nearest to heavy: money, perceived, round, represent, metal, stable, practical, markets,
# Nearest to grand: chinese, retained, car, emerged, irish, team, teaching, base,
# Nearest to police: base, recognition, bringing, soldiers, defense, changing, branches, training,
# Nearest to derived: meaning, names, words, latin, greek, language, word, origin,
# Nearest to resources: environment, extensive, complex, organization, ideas, trade, issues, natural,
# Nearest to prince: edward, visited, henry, treaty, entitled, remainder, got, duke,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 5.6341 0.0320 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 5.5577 0.0310 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 5.7692 0.0310 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 5.6193 0.0307 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 5.5242 0.0306 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 5.5750 0.0311 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 5.5434 0.0304 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 5.7101 0.0306 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 6.1685 0.0297 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 5.5570 0.0305 sec/batch
# Nearest to will: be, it, this, that, to, is, not, make,
# Nearest to s: the, of, in, by, and, a, was, from,
# Nearest to seven: one, eight, nine, six, five, three, four, zero,
# Nearest to world: war, the, ii, during, in, around, of, third,
# Nearest to history: of, article, the, in, on, first, see, culture,
# Nearest to as: such, well, known, is, of, a, the, this,
# Nearest to often: used, is, this, most, are, sometimes, as, in,
# Nearest to his: he, him, was, the, who, father, after, death,
# Nearest to san: francisco, california, bay, diego, street, running, office, replace,
# Nearest to nobel: prize, laureate, physicist, chemist, recipient, medicine, physiology, swiss,
# Nearest to heavy: perceived, money, metal, dangerous, purposes, contrast, practical, interesting,
# Nearest to grand: car, centre, generation, remarkable, seat, violent, favor, improved,
# Nearest to police: enter, branches, security, defense, base, headquarters, acts, powers,
# Nearest to derived: word, latin, names, words, meaning, origin, method, separate,
# Nearest to resources: our, complex, extensive, ideas, natural, issues, usual, rules,
# Nearest to prince: crown, entitled, edward, visited, princess, joseph, daughter, child,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 5.5815 0.0317 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 5.4297 0.0303 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 5.3698 0.0308 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 5.6426 0.0311 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 5.5616 0.0314 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 5.6270 0.0314 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 5.5622 0.0302 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 5.6814 0.0306 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 5.5392 0.0303 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 5.4225 0.0302 sec/batch
# Nearest to will: make, that, be, it, this, to, they, if,
# Nearest to s: the, in, of, one, by, and, nine, u,
# Nearest to seven: nine, one, eight, six, three, five, four, two,
# Nearest to world: war, ii, the, of, during, in, major, new,
# Nearest to history: of, the, study, article, early, historical, and, in,
# Nearest to as: such, well, known, a, this, is, the, to,
# Nearest to often: is, are, used, this, most, or, term, to,
# Nearest to his: he, was, death, the, him, life, later, first,
# Nearest to san: francisco, california, diego, running, completed, recorded, centre, street,
# Nearest to nobel: prize, physicist, laureate, chemist, recipient, winners, medicine, physiology,
# Nearest to heavy: perceived, cost, metal, money, room, expensive, requirements, charge,
# Nearest to grand: weapons, fans, car, completed, interpretation, generation, favor, coined,
# Nearest to police: defense, training, establish, security, soldiers, secret, branches, base,
# Nearest to derived: from, latin, meaning, word, use, this, is, its,
# Nearest to resources: natural, issues, environment, legal, interest, extensive, programs, usual,
# Nearest to prince: entitled, visited, crown, meeting, edward, principal, she, marked,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 5.5046 0.0312 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 5.4685 0.0300 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 5.5335 0.0300 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 5.6169 0.0305 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 5.4311 0.0303 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 5.6274 0.0305 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 5.6070 0.0302 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 5.3396 0.0299 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 5.4141 0.0300 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 5.4427 0.0301 sec/batch
# Nearest to will: it, that, this, be, to, if, not, is,
# Nearest to s: u, the, one, in, by, of, nine, from,
# Nearest to seven: nine, six, eight, one, five, four, three, zero,
# Nearest to world: war, the, of, in, largest, end, over, s,
# Nearest to history: of, the, important, in, see, first, on, by,
# Nearest to as: such, well, known, is, the, it, there, of,
# Nearest to often: is, are, used, this, it, important, most, considered,
# Nearest to his: he, him, father, was, after, life, death, the,
# Nearest to san: francisco, california, diego, empire, event, street, hit, break,
# Nearest to nobel: prize, laureate, physicist, chemist, winners, recipient, medicine, swiss,
# Nearest to heavy: metal, alternative, determined, maximum, dangerous, cost, extreme, purposes,
# Nearest to grand: students, everything, interpretation, favor, violent, event, stand, weapons,
# Nearest to police: soldiers, positions, opened, parliament, powers, defense, constitution, training,
# Nearest to derived: from, word, is, the, of, this, name, latin,
# Nearest to resources: natural, community, powerful, extensive, primary, interpretation, uk, access,
# Nearest to prince: entitled, inherited, visited, foreign, queen, henry, duke, throne,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 5.3895 0.0310 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 5.4281 0.0299 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 5.4185 0.0299 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 5.4418 0.0298 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 5.2840 0.0302 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 5.7568 0.0303 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 5.2931 0.0298 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 5.3719 0.0300 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 5.3508 0.0298 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 5.4554 0.0301 sec/batch
# Nearest to will: make, be, if, we, they, not, that, have,
# Nearest to s: the, of, in, u, a, and, was, by,
# Nearest to seven: eight, one, nine, six, five, four, three, two,
# Nearest to world: war, during, the, ii, of, in, and, to,
# Nearest to history: of, the, see, s, in, and, article, modern,
# Nearest to as: such, well, a, the, known, of, is, in,
# Nearest to often: is, used, sometimes, are, most, very, considered, the,
# Nearest to his: he, was, life, of, father, in, him, the,
# Nearest to san: francisco, california, bay, diego, run, break, adopted, town,
# Nearest to nobel: prize, laureate, chemist, physicist, recipient, medicine, physiology, winners,
# Nearest to heavy: metal, money, dangerous, relevant, representation, express, interesting, contact,
# Nearest to grand: students, favor, everything, irish, criticism, committee, weapons, key,
# Nearest to police: defense, shot, opened, officers, regime, secret, positions, soldiers,
# Nearest to derived: word, from, meaning, use, is, are, name, for,
# Nearest to resources: natural, organized, countries, discussion, cultural, issues, conflict, programs,
# Nearest to prince: entitled, crown, fellow, visited, sons, queen, duke, henry,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 5.5076 0.0309 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 5.6907 0.0298 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 5.7457 0.0302 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 5.3902 0.0308 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 5.2040 0.0314 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 5.2942 0.0312 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 5.5453 0.0316 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 5.6774 0.0299 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 5.5520 0.0295 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 5.6049 0.0295 sec/batch
# Nearest to will: make, be, we, that, it, is, so, they,
# Nearest to s: the, by, a, in, and, of, u, from,
# Nearest to seven: six, one, nine, eight, five, four, two, three,
# Nearest to world: war, the, during, country, of, in, and, from,
# Nearest to history: of, the, in, country, and, world, modern, times,
# Nearest to as: well, such, known, is, a, the, but, and,
# Nearest to often: is, used, are, more, referred, that, different, it,
# Nearest to his: he, him, was, death, father, after, life, had,
# Nearest to san: francisco, california, city, final, in, events, usa, home,
# Nearest to nobel: prize, laureate, chemist, recipient, medicine, physicist, physiology, winners,
# Nearest to heavy: metal, permitted, ordinary, requirements, weight, money, expensive, cost,
# Nearest to grand: duke, money, formally, hit, criticism, ruled, selected, favor,
# Nearest to police: defense, secret, regime, dominated, marked, training, effectively, security,
# Nearest to derived: word, meaning, from, name, is, other, the, use,
# Nearest to resources: natural, legal, countries, issues, organized, communities, information, conflict,
# Nearest to prince: crown, visited, henry, duke, opera, fellow, marked, constitution,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 5.4067 0.0304 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 5.4304 0.0297 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 5.2113 0.0300 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 5.2482 0.0307 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 5.4726 0.0296 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 5.1820 0.0302 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 5.2435 0.0302 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 5.5587 0.0304 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 5.4020 0.0306 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 5.2730 0.0304 sec/batch
# Nearest to will: this, be, they, to, it, that, all, is,
# Nearest to s: the, in, of, and, was, u, by, early,
# Nearest to seven: nine, one, eight, five, six, four, three, two,
# Nearest to world: war, the, during, of, in, ii, s, from,
# Nearest to history: culture, of, the, in, on, and, s, early,
# Nearest to as: well, such, known, the, a, is, this, of,
# Nearest to often: are, is, used, or, common, very, it, example,
# Nearest to his: he, him, was, had, father, after, with, the,
# Nearest to san: california, francisco, in, bay, home, city, at, one,
# Nearest to nobel: prize, laureate, physicist, chemist, recipient, physiology, medicine, scientist,
# Nearest to heavy: metal, ordinary, expensive, standing, purposes, marked, greatly, unusual,
# Nearest to grand: duke, russia, race, ruled, irish, executed, car, henry,
# Nearest to police: security, secret, powers, regime, defense, dominated, sign, officers,
# Nearest to derived: name, from, meaning, is, its, word, latin, common,
# Nearest to resources: natural, issues, information, communities, web, code, human, network,
# Nearest to prince: henry, queen, edward, crown, duke, royal, succeeded, russia,
# Epoch 2/10 Iteration: 23100 Avg. Training loss: 5.4072 0.0312 sec/batch
# Epoch 2/10 Iteration: 23200 Avg. Training loss: 5.3638 0.0302 sec/batch
# Epoch 2/10 Iteration: 23300 Avg. Training loss: 5.5160 0.0297 sec/batch
# Epoch 3/10 Iteration: 23400 Avg. Training loss: 5.4457 0.0251 sec/batch
# Epoch 3/10 Iteration: 23500 Avg. Training loss: 5.4398 0.0299 sec/batch
# Epoch 3/10 Iteration: 23600 Avg. Training loss: 5.3010 0.0300 sec/batch
# Epoch 3/10 Iteration: 23700 Avg. Training loss: 5.3397 0.0301 sec/batch
# Epoch 3/10 Iteration: 23800 Avg. Training loss: 5.1882 0.0297 sec/batch
# Epoch 3/10 Iteration: 23900 Avg. Training loss: 5.4053 0.0302 sec/batch
# Epoch 3/10 Iteration: 24000 Avg. Training loss: 5.4414 0.0298 sec/batch
# Nearest to will: they, that, what, be, is, not, to, this,
# Nearest to s: u, the, was, first, by, of, in, and,
# Nearest to seven: eight, one, six, nine, five, four, three, two,
# Nearest to world: war, the, of, in, during, first, around, about,
# Nearest to history: of, early, the, s, first, in, see, sources,
# Nearest to as: well, such, known, a, is, the, to, this,
# Nearest to often: is, used, or, most, are, many, usually, considered,
# Nearest to his: he, him, was, after, father, life, the, had,
# Nearest to san: francisco, california, city, home, bay, in, france, national,
# Nearest to nobel: prize, laureate, chemist, physicist, recipient, physiology, medicine, scientist,
# Nearest to heavy: metal, standing, represent, cost, understanding, seem, product, ordinary,
# Nearest to grand: duke, rome, host, irish, winning, centre, final, reported,
# Nearest to police: secret, security, officers, guard, defense, authorities, powers, pay,
# Nearest to derived: name, from, word, latin, meaning, for, use, are,
# Nearest to resources: natural, provides, issues, web, extensive, communities, information, environment,
# Nearest to prince: henry, duke, queen, russia, succeeded, albert, edward, royal,
# Epoch 3/10 Iteration: 24100 Avg. Training loss: 5.2185 0.0319 sec/batch
# Epoch 3/10 Iteration: 24200 Avg. Training loss: 5.3399 0.0298 sec/batch
# Epoch 3/10 Iteration: 24300 Avg. Training loss: 5.2257 0.0296 sec/batch
# Epoch 3/10 Iteration: 24400 Avg. Training loss: 5.2350 0.0300 sec/batch
# Epoch 3/10 Iteration: 24500 Avg. Training loss: 5.3814 0.0297 sec/batch
# Epoch 3/10 Iteration: 24600 Avg. Training loss: 5.4627 0.0302 sec/batch
# Epoch 3/10 Iteration: 24700 Avg. Training loss: 5.3348 0.0301 sec/batch
# Epoch 3/10 Iteration: 24800 Avg. Training loss: 5.1995 0.0301 sec/batch
# Epoch 3/10 Iteration: 24900 Avg. Training loss: 5.2690 0.0309 sec/batch
# Epoch 3/10 Iteration: 25000 Avg. Training loss: 5.1189 0.0301 sec/batch
# Nearest to will: they, be, that, it, to, make, not, come,
# Nearest to s: the, u, in, of, was, and, zero, nine,
# Nearest to seven: one, eight, nine, six, five, four, three, zero,
# Nearest to world: war, the, during, in, of, country, its, s,
# Nearest to history: of, culture, the, article, early, first, see, in,
# Nearest to as: well, such, known, for, that, this, a, and,
# Nearest to often: most, are, or, used, common, because, is, that,
# Nearest to his: he, was, him, father, before, death, life, after,
# Nearest to san: california, francisco, city, one, nine, the, in, eight,
# Nearest to nobel: prize, physicist, laureate, chemist, recipient, scientist, physiology, swiss,
# Nearest to heavy: metal, table, cut, bound, overall, ones, understanding, cost,
# Nearest to grand: duke, figure, final, prince, the, of, one, russia,
# Nearest to police: security, secret, defense, regime, principal, soldiers, founding, split,
# Nearest to derived: word, name, latin, from, meaning, use, is, other,
# Nearest to resources: natural, large, environment, access, research, issues, of, worldwide,
# Nearest to prince: duke, henry, king, queen, edward, one, nine, eight,
# Epoch 3/10 Iteration: 25100 Avg. Training loss: 5.2702 0.0311 sec/batch
# Epoch 3/10 Iteration: 25200 Avg. Training loss: 5.1360 0.0299 sec/batch
# Epoch 3/10 Iteration: 25300 Avg. Training loss: 5.2960 0.0302 sec/batch
# Epoch 3/10 Iteration: 25400 Avg. Training loss: 5.0990 0.0303 sec/batch
# Epoch 3/10 Iteration: 25500 Avg. Training loss: 5.1686 0.0303 sec/batch
# Epoch 3/10 Iteration: 25600 Avg. Training loss: 5.2257 0.0302 sec/batch
# Epoch 3/10 Iteration: 25700 Avg. Training loss: 5.3089 0.0301 sec/batch
# Epoch 3/10 Iteration: 25800 Avg. Training loss: 5.2407 0.0303 sec/batch
# Epoch 3/10 Iteration: 25900 Avg. Training loss: 5.3082 0.0300 sec/batch
# Epoch 3/10 Iteration: 26000 Avg. Training loss: 5.0097 0.0302 sec/batch
# Nearest to will: be, they, to, that, or, need, not, would,
# Nearest to s: the, in, of, by, was, one, u, and,
# Nearest to seven: eight, one, nine, four, five, six, zero, three,
# Nearest to world: war, during, the, in, second, s, after, and,
# Nearest to history: of, the, see, culture, museum, and, in, first,
# Nearest to as: well, such, known, in, the, this, a, is,
# Nearest to often: is, used, are, or, this, more, such, that,
# Nearest to his: he, him, was, father, after, and, to, before,
# ...
# Epoch 10/10 Iteration: 108700 Avg. Training loss: 4.1890 0.0300 sec/batch
# Epoch 10/10 Iteration: 108800 Avg. Training loss: 4.1809 0.0302 sec/batch
# Epoch 10/10 Iteration: 108900 Avg. Training loss: 4.1603 0.0304 sec/batch
# Epoch 10/10 Iteration: 109000 Avg. Training loss: 4.1530 0.0308 sec/batch
# Nearest to will: be, need, cannot, you, give, must, unless, if,
# Nearest to s: u, the, nine, zero, one, late, smith, in,
# Nearest to seven: nine, eight, six, one, five, three, four, zero,
# Nearest to world: war, around, throughout, the, largest, during, ii, major,
# Nearest to history: article, early, see, historical, page, timeline, origins, geography,
# Nearest to as: such, well, known, referred, regarded, a, is, described,
# Nearest to often: used, sometimes, referred, frequently, usually, commonly, are, is,
# Nearest to his: he, him, father, wife, son, died, own, death,
# Nearest to san: francisco, diego, jose, california, los, angeles, juan, santa,
# Nearest to nobel: prize, laureate, physiology, physicist, chemist, awarded, biologist, recipient,
# Nearest to heavy: metal, infantry, mounted, lighter, tank, armor, guns, combat,
# Nearest to grand: poland, prix, lithuania, duke, title, east, knights, sweden,
# Nearest to police: officers, officer, patrol, armed, defence, enforcement, defense, army,
# Nearest to derived: meaning, word, derives, from, latin, comes, term, derive,
# Nearest to resources: resource, natural, environment, access, information, extensive, large, global,
# Nearest to prince: edward, island, duke, wales, queen, scotia, nova, victoria,
# Epoch 10/10 Iteration: 109100 Avg. Training loss: 4.2284 0.0317 sec/batch
# Epoch 10/10 Iteration: 109200 Avg. Training loss: 4.1757 0.0313 sec/batch
# Epoch 10/10 Iteration: 109300 Avg. Training loss: 4.1618 0.0314 sec/batch
# Epoch 10/10 Iteration: 109400 Avg. Training loss: 4.1560 0.0307 sec/batch
# Epoch 10/10 Iteration: 109500 Avg. Training loss: 4.1574 0.0309 sec/batch
# Epoch 10/10 Iteration: 109600 Avg. Training loss: 4.2173 0.0304 sec/batch
# Epoch 10/10 Iteration: 109700 Avg. Training loss: 4.2310 0.0303 sec/batch
# Epoch 10/10 Iteration: 109800 Avg. Training loss: 4.2278 0.0301 sec/batch
# Epoch 10/10 Iteration: 109900 Avg. Training loss: 4.1717 0.0303 sec/batch
# Epoch 10/10 Iteration: 110000 Avg. Training loss: 4.0540 0.0304 sec/batch
# Nearest to will: you, if, make, need, be, would, do, depend,
# Nearest to s: u, nine, one, mid, the, early, zero, eight,
# Nearest to seven: one, eight, nine, six, five, four, three, two,
# Nearest to world: war, ii, largest, the, around, history, biggest, nations,
# Nearest to history: article, historical, geography, origins, timeline, links, external, early,
# Nearest to as: well, such, known, referred, described, interpreted, generally, is,
# Nearest to often: sometimes, used, referred, term, as, associated, are, cited,
# Nearest to his: he, him, career, wife, himself, father, friend, wrote,
# Nearest to san: francisco, diego, california, jose, los, santa, juan, bay,
# Nearest to nobel: prize, laureate, physicist, chemist, writer, recipient, scientist, swiss,
# Nearest to heavy: metal, heavier, iron, combat, mounted, infantry, fire, steel,
# Nearest to grand: prix, knights, duke, museum, poland, won, louis, duchy,
# Nearest to police: officer, officers, defense, department, staff, defence, personnel, crime,
# Nearest to derived: derives, meaning, word, latin, etymology, greek, derive, from,
# Nearest to resources: resource, information, natural, services, extensive, mining, and, info,
# Nearest to prince: edward, queen, king, duke, island, son, albert, royal,
# Epoch 10/10 Iteration: 110100 Avg. Training loss: 4.1702 0.0312 sec/batch
# Epoch 10/10 Iteration: 110200 Avg. Training loss: 4.0838 0.0300 sec/batch
# Epoch 10/10 Iteration: 110300 Avg. Training loss: 4.1794 0.0303 sec/batch
# Epoch 10/10 Iteration: 110400 Avg. Training loss: 4.1752 0.0300 sec/batch
# Epoch 10/10 Iteration: 110500 Avg. Training loss: 4.1467 0.0300 sec/batch
# Epoch 10/10 Iteration: 110600 Avg. Training loss: 4.2245 0.0306 sec/batch
# Epoch 10/10 Iteration: 110700 Avg. Training loss: 4.1463 0.0305 sec/batch
# Epoch 10/10 Iteration: 110800 Avg. Training loss: 4.1259 0.0303 sec/batch
# Epoch 10/10 Iteration: 110900 Avg. Training loss: 4.1333 0.0300 sec/batch
# Epoch 10/10 Iteration: 111000 Avg. Training loss: 4.1143 0.0300 sec/batch
# Nearest to will: be, if, you, need, can, we, should, to,
# Nearest to s: u, zero, the, nine, his, peter, of, was,
# Nearest to seven: eight, one, six, nine, five, three, d, four,
# Nearest to world: war, ii, cup, during, championships, championship, champions, tournament,
# Nearest to history: links, timeline, external, historical, article, museum, politics, biography,
# Nearest to as: well, such, known, referred, regarded, described, seen, often,
# Nearest to often: sometimes, used, referred, usually, as, commonly, are, term,
# Nearest to his: he, him, career, wife, father, himself, her, death,
# Nearest to san: francisco, diego, jose, california, santa, antonio, los, santiago,
# Nearest to nobel: prize, laureate, physicist, chemist, physiology, medicine, recipient, biologist,
# Nearest to heavy: metal, low, lighter, heavier, fired, guns, lead, vehicles,
# Nearest to grand: prix, racing, won, auto, championship, knights, cup, title,
# Nearest to police: officer, armed, arrested, officers, soldiers, defence, guard, personnel,
# Nearest to derived: meaning, word, etymology, derive, greek, derives, from, names,
# Nearest to resources: resource, natural, links, information, com, info, site, websites,
# Nearest to prince: crown, son, throne, princess, emperor, brother, father, empress,
# Epoch 10/10 Iteration: 111100 Avg. Training loss: 4.1948 0.0312 sec/batch
# Epoch 10/10 Iteration: 111200 Avg. Training loss: 4.1433 0.0294 sec/batch
# Epoch 10/10 Iteration: 111300 Avg. Training loss: 4.1642 0.0301 sec/batch
# Epoch 10/10 Iteration: 111400 Avg. Training loss: 4.1729 0.0302 sec/batch
# Epoch 10/10 Iteration: 111500 Avg. Training loss: 4.1305 0.0304 sec/batch
# Epoch 10/10 Iteration: 111600 Avg. Training loss: 3.9886 0.0299 sec/batch
# Epoch 10/10 Iteration: 111700 Avg. Training loss: 4.2112 0.0300 sec/batch
# Epoch 10/10 Iteration: 111800 Avg. Training loss: 4.1942 0.0302 sec/batch
# Epoch 10/10 Iteration: 111900 Avg. Training loss: 4.1666 0.0302 sec/batch
# Epoch 10/10 Iteration: 112000 Avg. Training loss: 4.2068 0.0303 sec/batch
# Nearest to will: you, if, be, must, do, would, your, we,
# Nearest to s: u, his, nine, one, book, the, peter, was,
# Nearest to seven: one, nine, eight, six, five, four, three, two,
# Nearest to world: war, ii, championship, cup, champions, championships, winning, europe,
# Nearest to history: historical, timeline, see, origins, article, modern, culture, external,
# Nearest to as: well, such, known, referred, regarded, described, a, interpreted,
# Nearest to often: sometimes, are, referred, used, associated, as, is, usually,
# Nearest to his: he, career, wife, father, him, work, himself, friend,
# Nearest to san: francisco, diego, santa, antonio, jose, california, los, juan,
# Nearest to nobel: prize, laureate, physiology, medicine, chemist, physicist, biologist, recipient,
# Nearest to heavy: metal, due, heavier, mounted, very, low, heat, caused,
# Nearest to grand: prix, auto, theft, circuit, racing, championship, court, masters,
# Nearest to police: armed, personnel, officers, officer, operations, arrested, civilians, army,
# Nearest to derived: derives, word, latin, name, derive, meaning, from, english,
# Nearest to resources: resource, natural, links, external, information, web, website, extensive,
# Nearest to prince: crown, throne, princess, emperor, son, brother, regent, king,
# Epoch 10/10 Iteration: 112100 Avg. Training loss: 4.2572 0.0318 sec/batch
# Epoch 10/10 Iteration: 112200 Avg. Training loss: 4.1199 0.0309 sec/batch
# Epoch 10/10 Iteration: 112300 Avg. Training loss: 4.1025 0.0304 sec/batch
# Epoch 10/10 Iteration: 112400 Avg. Training loss: 4.1927 0.0301 sec/batch
# Epoch 10/10 Iteration: 112500 Avg. Training loss: 4.1500 0.0301 sec/batch
# Epoch 10/10 Iteration: 112600 Avg. Training loss: 4.1660 0.0309 sec/batch
# Epoch 10/10 Iteration: 112700 Avg. Training loss: 4.1581 0.0299 sec/batch
# Epoch 10/10 Iteration: 112800 Avg. Training loss: 4.1626 0.0297 sec/batch
# Epoch 10/10 Iteration: 112900 Avg. Training loss: 4.1774 0.0298 sec/batch
# Epoch 10/10 Iteration: 113000 Avg. Training loss: 4.1690 0.0297 sec/batch
# Nearest to will: you, be, if, can, do, they, go, must,
# Nearest to s: u, late, his, the, nine, one, father, zero,
# Nearest to seven: one, eight, nine, six, five, four, two, three,
# Nearest to world: war, largest, europe, wide, history, during, around, throughout,
# Nearest to history: links, timeline, article, ancient, external, see, chronology, historical,
# Nearest to as: such, well, known, regarded, referred, used, is, a,
# Nearest to often: sometimes, are, is, usually, frequently, or, used, referred,
# Nearest to his: he, father, wife, him, son, brother, death, sons,
# Nearest to san: francisco, diego, antonio, santa, jose, los, california, miami,
# Nearest to nobel: prize, laureate, awarded, winners, chemistry, chemist, physiology, medicine,
# Nearest to heavy: metal, rock, bands, water, heavier, pure, air, cool,
# Nearest to grand: prix, auto, duke, titles, title, masters, theft, held,
# Nearest to police: officers, armed, personnel, forces, officer, civilians, force, defence,
# Nearest to derived: derives, meaning, name, word, from, latin, words, etymology,
# Nearest to resources: resource, natural, links, extensive, information, external, history, website,
# Nearest to prince: son, princess, crown, king, regent, brother, duke, daughter,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 4.0533 0.0310 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 4.1088 0.0297 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 4.1374 0.0294 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 4.1916 0.0295 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 4.1460 0.0299 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 4.1329 0.0297 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 4.1149 0.0300 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 3.8957 0.0297 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 4.0457 0.0299 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 4.0865 0.0299 sec/batch
# Nearest to will: you, do, we, be, your, if, me, good,
# Nearest to s: u, his, the, john, death, during, a, in,
# Nearest to seven: one, eight, six, nine, five, four, b, three,
# Nearest to world: war, ii, largest, around, end, during, the, second,
# Nearest to history: timeline, links, ancient, historical, article, external, chronology, references,
# Nearest to as: well, known, such, regarded, referred, a, he, his,
# Nearest to often: sometimes, frequently, used, referred, simply, cited, usually, called,
# Nearest to his: he, career, him, was, father, wrote, work, own,
# Nearest to san: francisco, diego, california, antonio, jose, los, santiago, santa,
# Nearest to nobel: prize, laureate, recipient, medicine, physiology, physicist, chemist, german,
# Nearest to heavy: metal, bands, water, cool, cold, air, losses, wind,
# Nearest to grand: duke, prix, auto, prince, louis, iii, one, eight,
# Nearest to police: officers, personnel, officer, headquarters, force, military, armed, defence,
# Nearest to derived: word, meaning, derives, name, latin, etymology, stems, hebrew,
# Nearest to resources: natural, resource, issues, petroleum, land, environment, mining, soil,
# Nearest to prince: princess, crown, duke, queen, regent, emperor, edward, king,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 4.1160 0.0308 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 4.1806 0.0305 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 4.1816 0.0306 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 4.2592 0.0305 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.2916 0.0306 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.2887 0.0306 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 4.1552 0.0303 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 3.9979 0.0306 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 4.1204 0.0302 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.2478 0.0302 sec/batch
# Nearest to will: we, be, you, must, can, do, happen, allow,
# Nearest to s: u, in, the, nine, one, of, by, r,
# Nearest to seven: one, six, nine, eight, five, four, three, two,
# Nearest to world: war, ii, largest, renowned, europe, second, during, cup,
# Nearest to history: origins, ancient, links, historical, archaeology, article, timeline, earliest,
# Nearest to as: well, such, known, viewed, referred, regarded, seen, a,
# Nearest to often: sometimes, usually, referred, frequently, associated, used, are, more,
# Nearest to his: he, father, wife, him, himself, death, work, friend,
# Nearest to san: francisco, california, los, diego, antonio, jose, angeles, mexico,
# Nearest to nobel: prize, laureate, physiology, medicine, physicist, chemist, biologist, winners,
# Nearest to heavy: metal, cold, cool, bands, water, hot, vehicles, deep,
# Nearest to grand: duke, prix, duchy, princes, prince, title, king, auto,
# Nearest to police: headquarters, officers, personnel, arrested, armed, staff, guard, secret,
# Nearest to derived: word, meaning, name, derives, etymology, from, words, latin,
# Nearest to resources: natural, resource, land, oil, petroleum, issues, mining, extraction,
# Nearest to prince: crown, monarch, princess, king, queen, regent, son, emperor,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 4.1812 0.0321 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.1594 0.0300 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 4.2305 0.0302 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.1258 0.0302 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 4.1534 0.0304 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 3.9431 0.0299 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 4.0898 0.0300 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 4.1706 0.0301 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 4.0242 0.0301 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 4.1358 0.0300 sec/batch
# Nearest to will: you, choose, we, be, if, can, must, continue,
# Nearest to s: u, the, mid, zero, first, president, by, became,
# Nearest to seven: one, six, eight, nine, four, five, zero, three,
# Nearest to world: war, ii, largest, first, the, during, germany, japan,
# Nearest to history: timeline, historical, earliest, links, origins, see, references, article,
# Nearest to as: well, such, known, referred, viewed, regarded, a, seen,
# Nearest to often: associated, commonly, sometimes, used, frequently, referred, are, different,
# Nearest to his: he, him, father, himself, wife, friend, son, writings,
# Nearest to san: francisco, jose, diego, antonio, california, los, santiago, juan,
# Nearest to nobel: prize, laureate, recipient, physiology, chemist, physicist, biologist, writer,
# Nearest to heavy: metal, bands, band, steel, massive, vehicles, cold, soft,
# Nearest to grand: duke, prix, duchy, prince, iii, louis, king, imperial,
# Nearest to police: officers, arrested, guard, personnel, armed, killed, defence, officer,
# Nearest to derived: word, from, etymology, stems, meaning, latin, derives, name,
# Nearest to resources: resource, natural, land, sites, issues, information, exploited, com,
# Nearest to prince: crown, duke, queen, king, princess, regent, iii, throne,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 4.1626 0.0308 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 4.1464 0.0303 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 4.1266 0.0299 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 4.1611 0.0300 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 4.1795 0.0303 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 4.2272 0.0302 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
